# %%
import pandas as pd
from scipy import signal, stats

# %%
df_facility = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/overpass/facility_numbers.csv',index_col=0)
df_corr = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/src/basic_analysis/基本統計量.csv',index_col=0)
df_kankou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/kankou/fix_kankoukyaku.csv',index_col=0)
df_zinkou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/zinkou/zinkou.csv',index_col=0)
df_distance = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/distance/cal_distance.csv',index_col=0)

# %%
df_distance = df_distance.iloc[1:,8]

# %%
df_zinkou = df_zinkou.iloc[1:,0]

# %%
df_corr = df_corr.iloc[1:9,:]

# %%
df_corr
# Out:
#          相関係数            p値    人口平均   人口中央値       人口合計        人口分散  人口標準偏差
# 嵐山   0.653550  7.802838e-46   13271   12286    4844123    10647239    3263  \
# 中京区 -0.186082  3.513405e-04  502359  504733  183361385   535984480   23151
# 金閣寺  0.019234  7.141892e-01  171207  170789   62490734    48630493    6973
# 清水寺  0.739777  1.934243e-64  133314  130088   48659663   334391725   18286
# 学生街  0.135085  9.772009e-03  264123  260333   96405085   142359219   11931
# 二条城  0.476659  4.200543e-22  336931  336494  122980129    85780900    9261
# 東寺   0.180932  5.136091e-04  306050  311300  111708322   340225888   18445
# 京都駅  0.692329  2.177144e-53  520432  518560  189957943  3921620476   62622
#
#       人口最大値   人口最小値  人口四分位点(25%)  ...  発言者数平均  発言者数中央値  発言者数合計  発言者数分散
# 嵐山    31878    8283        11129  ...       3        3    1435      11  \
# 中京区  574213  427979       491376  ...      20       19    7357      61
# 金閣寺  198368  153176       167409  ...       3        3    1334       8
# 清水寺  214854   96328       121450  ...      16       14    5848      76
# 学生街  307985  231228       256559  ...       5        5    2046       4
# 二条城  369489  307399       330973  ...      11       11    4343      29
# 東寺   339703  239481       305621  ...       4        4    1649      10
# 京都駅  693690  352372       486877  ...     223      209   81522    6100
#
#      発言者数標準偏差  発言者数最大値  発言者数最小値  発言者数四分位点(25%)  発言者数四分位点(75%)  発言者数中央値/人口中央値
# 嵐山          3       21        0              2              5       0.000244
# 中京区         7       59        5             15             24       0.000038
# 金閣寺         2       17        0              2              5       0.000018
# 清水寺         8       57        1             10             21       0.000108
# 学生街         2       16        0              4              7       0.000019
# 二条城         5       37        1              8             15       0.000033
# 東寺          3       19        0              2              6       0.000013
# 京都駅        78      486       80            169            274       0.000403
#
# [8 rows x 21 columns]

# %%
df_merge = df_corr.merge(df_facility,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_kankou,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_zinkou,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_distance,left_index=True,right_index=True)

# %%
df_merge
# Out:
#          相関係数            p値    人口平均   人口中央値       人口合計        人口分散  人口標準偏差
# restaurant     0.147495 -0.033911 -0.500464
# school         0.236734 -0.006736 -0.389386
# bus_stop       0.240961  0.117468 -0.453617
# hotel          0.332721 -0.197597 -0.419911
# 観光客全体          0.996856 -0.564474  0.414240
# 観光客男           0.993575 -0.584594  0.434377
# 観光客女           0.996932 -0.552267  0.401461
# 観光客１９歳以下       0.935501 -0.565433  0.458672
# 観光客20代         0.993667 -0.607464  0.407303
# 観光客30代         0.985579 -0.507867  0.320763
# 観光客40代         0.973229 -0.514253  0.434279
# 観光客50代         0.992812 -0.550214  0.424731
# 観光客60歳以上       1.000000 -0.603385  0.422289
# 居住者数（総数）      -0.603385  1.000000 -0.570847
# 駅距離            0.422289 -0.570847  1.000000
#
# [37 rows x 37 columns]

# %%
df_merge.columns
# Out:
# Index(['相関係数', 'p値', '人口平均', '人口中央値', '人口合計', '人口分散', '人口標準偏差', '人口最大値',
#        '人口最小値', '人口四分位点(25%)', '人口四分位点(75%)', '発言者数平均', '発言者数中央値', '発言者数合計',
#        '発言者数分散', '発言者数標準偏差', '発言者数最大値', '発言者数最小値', '発言者数四分位点(25%)',
#        '発言者数四分位点(75%)', '発言者数中央値/人口中央値', 'convenience', 'restaurant', 'school',
#        'bus_stop', 'hotel', '観光客全体', '観光客男', '観光客女', '観光客１９歳以下', '観光客20代',
#        '観光客30代', '観光客40代', '観光客50代', '観光客60歳以上', '居住者数（総数）', '駅距離'],
#       dtype='object')

# %%
rank_r = []
for i in df_merge.columns:
    corr, pvalue = stats.spearmanr(df_merge.rank()['相関係数'], df_merge.rank()[i])
    rank_r.append([corr, pvalue])

df_rank = pd.DataFrame(rank_r,index=df_merge.columns, columns=['順位相関係数','p値'])
# df_rank.to_csv('順位相関.csv')

r_r = []
for i in df_merge.columns:
    corr, pvalue = stats.pearsonr(df_merge['相関係数'], df_merge[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge.columns, columns=['相関係数','p値'])
# df_r.to_csv('相関.csv')

# %%
df_rank
# Out:
#                  順位相関係数        p値
# 相関係数           1.000000  0.000000
# p値            -0.857143  0.006530
# 人口平均          -0.214286  0.610344
# 人口中央値         -0.214286  0.610344
# 人口合計          -0.214286  0.610344
# 人口分散           0.047619  0.910849
# 人口標準偏差         0.047619  0.910849
# 人口最大値         -0.071429  0.866526
# 人口最小値         -0.357143  0.385121
# 人口四分位点(25%)   -0.357143  0.385121
# 人口四分位点(75%)   -0.214286  0.610344
# 発言者数平均         0.239525  0.567772
# 発言者数中央値        0.239525  0.567772
# 発言者数合計         0.285714  0.492726
# 発言者数分散         0.571429  0.138960
# 発言者数標準偏差       0.566306  0.143354
# 発言者数最大値        0.404762  0.319889
# 発言者数最小値        0.255405  0.541534
# 発言者数四分位点(25%)  0.243975  0.560376
# 発言者数四分位点(75%)  0.239525  0.567772
# 発言者数中央値/人口中央値  0.619048  0.101733
# convenience   -0.253030  0.545429
# restaurant     0.261905  0.530923
# school         0.327327  0.428692
# bus_stop      -0.227549  0.587845
# hotel          0.291724  0.483258
# 観光客全体          0.874267  0.004512
# 観光客男           0.874267  0.004512
# 観光客女           0.874267  0.004512
# 観光客１９歳以下       0.898220  0.002439
# 観光客20代         0.874267  0.004512
# 観光客30代         0.826362  0.011443
# 観光客40代         0.850315  0.007471
# 観光客50代         0.867533  0.005249
# 観光客60歳以上       0.874267  0.004512
# 居住者数（総数）      -0.738095  0.036553
# 駅距離            0.304408  0.463515

# %%
df_r
# Out:
#                    相関係数        p値
# 相関係数           1.000000  0.000000
# p値            -0.375605  0.359174
# 人口平均          -0.310256  0.454524
# 人口中央値         -0.316863  0.444451
# 人口合計          -0.310256  0.454524
# 人口分散           0.358454  0.383252
# 人口標準偏差         0.263572  0.528214
# 人口最大値         -0.173220  0.681651
# 人口最小値         -0.448167  0.265426
# 人口四分位点(25%)   -0.344786  0.402933
# 人口四分位点(75%)   -0.270587  0.516871
# 発言者数平均         0.402839  0.322415
# 発言者数中央値        0.400031  0.326118
# 発言者数合計         0.403580  0.321440
# 発言者数分散         0.412354  0.310009
# 発言者数標準偏差       0.426928  0.291460
# 発言者数最大値        0.416217  0.305040
# 発言者数最小値        0.384112  0.347495
# 発言者数四分位点(25%)  0.396607  0.330663
# 発言者数四分位点(75%)  0.407508  0.316299
# 発言者数中央値/人口中央値  0.680542  0.063224
# convenience   -0.104280  0.805888
# restaurant     0.143554  0.734511
# school         0.281781  0.498961
# bus_stop       0.079784  0.851039
# hotel          0.348624  0.397362
# 観光客全体          0.730961  0.039389
# 観光客男           0.748889  0.032505
# 観光客女           0.720041  0.043983
# 観光客１９歳以下       0.767331  0.026250
# 観光客20代         0.777318  0.023200
# 観光客30代         0.678710  0.064219
# 観光客40代         0.692487  0.056963
# 観光客50代         0.719364  0.044278
# 観光客60歳以上       0.750726  0.031845
# 居住者数（総数）      -0.809730  0.014857
# 駅距離            0.210719  0.616441

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/ソーシャルセンサ性能との相関.csv')

# %%
df_extraction = df_merge.loc[:,['人口合計','発言者数合計','観光客全体','居住者数（総数）']]

# %%
df_extraction.corr()
# Out:
#               人口合計    発言者数合計     観光客全体  居住者数（総数）
# 人口合計      1.000000  0.587478 -0.093702  0.565816
# 発言者数合計    0.587478  1.000000  0.369452 -0.235251
# 観光客全体    -0.093702  0.369452  1.000000 -0.564474
# 居住者数（総数）  0.565816 -0.235251 -0.564474  1.000000

# %%
len(df_extraction.columns)
# Out:
# 4

# %%
tmp=[]
index=[]
for i in range(0,4):
    i_key = df_extraction.columns[i]
    for j in range(0,4):
        j_key = df_extraction.columns[j]
        if i >= j:
            continue
        else:
            corr, pvalue = stats.pearsonr(df_merge[i_key], df_merge[j_key])
            tmp.append([corr,pvalue])
            index.append(str(i_key)+ "&"+str(j_key))
df_ = pd.DataFrame(tmp,index=index, columns=['相関係数','p値'])

# %%
#df_.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/人口, 発言数と観光客, 居住者数の相関.csv')
