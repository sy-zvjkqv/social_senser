# %%
import pandas as pd
from scipy import signal, stats

# %%
df_facility = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/overpass/facility_numbers.csv',index_col=0)
df_corr_work = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/re/基本統計量_work.csv',index_col=0)
df_corr_holi = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/re/基本統計量_holi.csv',index_col=0)
df_kankou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/kankou/fix_kankoukyaku.csv',index_col=0)
df_zinkou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/zinkou/zinkou.csv',index_col=0)
df_distance = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/distance/cal_distance.csv',index_col=0)

# %%
df_kankou = df_kankou.iloc[:,0]

# %%
df_distance = df_distance.iloc[:,8]

# %%
df_zinkou = df_zinkou.iloc[:,0]

# %%
df_corr_work
# Out:
#      ソーシャルセンサ性能(平日)        p値(平日)  人口平均(平日)  人口中央値(平日)   人口合計(平日)
# 東京駅        0.620190  3.203299e-27   1307140    1271980  317635103  \
# 嵐山         0.595285  1.355036e-24     12282      11754    2972255
# 中京区        0.046130  4.750590e-01    512192     508718  123950513
# 金閣寺        0.032601  6.137928e-01    170548     170080   41272838
# 清水寺        0.653407  7.547537e-31    128287     126259   31045594
# 学生街        0.002835  9.650105e-01    260841     258224   63123745
# 二条城        0.268362  2.326630e-05    334089     334309   80849653
# 東寺         0.233973  2.406469e-04    308092     312996   74558417
# 京都駅        0.815094  7.967674e-59    510708     510268  123591427
#
#         人口分散(平日)  人口最大値(平日)  人口最小値(平日)  発言者数平均(平日)  発言者数中央値(平日)  発言者数合計(平日)
# 東京駅  22812655900    1670289     846460         167          162       40633  \
# 嵐山       5826962      23167       8283           3            3         777
# 中京区    273510598     565428     456431          17           17        4213
# ...

# %%
df_merge_work = df_corr_work.merge(df_facility,left_index=True,right_index=True)
df_merge_holi = df_corr_holi.merge(df_facility,left_index=True,right_index=True)

# %%
df_merge_work = df_merge_work.merge(df_kankou,left_index=True,right_index=True)
df_merge_holi = df_merge_holi.merge(df_kankou,left_index=True,right_index=True)

# %%
df_merge_work = df_merge_work.merge(df_zinkou,left_index=True,right_index=True)
df_merge_holi = df_merge_holi.merge(df_zinkou,left_index=True,right_index=True)

# %%
df_merge_work = df_merge_work.merge(df_distance,left_index=True,right_index=True)
df_merge_holi = df_merge_holi.merge(df_distance,left_index=True,right_index=True)

# %%
df_merge_work.corr()
# Out:
#                    ソーシャルセンサ性能(平日)    p値(平日)  人口平均(平日)  人口中央値(平日)  人口合計(平日)
# ソーシャルセンサ性能(平日)           1.000000 -0.772433  0.235622   0.233126  0.236082  \
# p値(平日)                  -0.772433  1.000000 -0.188447  -0.189519 -0.188752
# 人口平均(平日)                 0.235622 -0.188447  1.000000   0.999893  0.999998
# 人口中央値(平日)                0.233126 -0.189519  0.999893   1.000000  0.999864
# 人口合計(平日)                 0.236082 -0.188752  0.999998   0.999864  1.000000
# 人口分散(平日)                 0.375240 -0.265671  0.924347   0.919449  0.925102
# 人口最大値(平日)                0.291356 -0.211369  0.997020   0.996254  0.997115
# 人口最小値(平日)                0.122959 -0.114708  0.985097   0.986588  0.984813
# 発言者数平均(平日)               0.654233 -0.357184  0.749869   0.751631  0.749587
# 発言者数中央値(平日)              0.657556 -0.356406  0.732328   0.734352  0.732007
# 発言者数合計(平日)               0.654390 -0.358201  0.749974   0.751742  0.749692
# ...

# %%
df_merge_work.columns
# Out:
# Index(['ソーシャルセンサ性能(平日)', 'p値(平日)', '人口平均(平日)', '人口中央値(平日)', '人口合計(平日)',
#        '人口分散(平日)', '人口最大値(平日)', '人口最小値(平日)', '発言者数平均(平日)', '発言者数中央値(平日)',
#        '発言者数合計(平日)', '発言者数分散(平日)', '発言者数最大値(平日)', '発言者数最小値(平日)',
#        '発言者数中央値/人口中央値(平日)', 'convenience', 'restaurant', 'school', 'bus_stop',
#        'hotel', '観光客全体', '居住者数（総数）'],
#       dtype='object')

# %%
r_r = []
for i in df_merge_work.columns:
    corr, pvalue = stats.pearsonr(df_merge_work['ソーシャルセンサ性能(平日)'], df_merge_work[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge_work.columns, columns=['ソーシャルセンサ性能(平日)','p値'])

# %%
df_r
# Out:
#                    ソーシャルセンサ性能(平日)        p値
# ソーシャルセンサ性能(平日)           1.000000  0.000000
# p値(平日)                  -0.772433  0.014697
# 人口平均(平日)                 0.235622  0.541651
# 人口中央値(平日)                0.233126  0.546065
# 人口合計(平日)                 0.236082  0.540838
# 人口分散(平日)                 0.375240  0.319678
# 人口最大値(平日)                0.291356  0.446854
# 人口最小値(平日)                0.122959  0.752645
# 発言者数平均(平日)               0.654233  0.055913
# 発言者数中央値(平日)              0.657556  0.054254
# 発言者数合計(平日)               0.654390  0.055834
# 発言者数分散(平日)               0.667707  0.049381
# 発言者数最大値(平日)              0.657585  0.054240
# 発言者数最小値(平日)              0.640946  0.062868
# 発言者数中央値/人口中央値(平日)        0.825792  0.006100
# convenience              0.320691  0.400124
# restaurant               0.518245  0.152915
# school                   0.448194  0.226311
# bus_stop                 0.399810  0.286356
# hotel                    0.582138  0.100049
# ...

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/re/ソーシャルセンサ性能との相関(平日).csv')

# %%
r_r = []
for i in df_merge_holi.columns:
    corr, pvalue = stats.pearsonr(df_merge_holi['ソーシャルセンサ性能(休日)'], df_merge_holi[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge_holi.columns, columns=['ソーシャルセンサ性能(休日)','p値'])

# %%
df_r
# Out:
#                    ソーシャルセンサ性能(休日)        p値
# ソーシャルセンサ性能(休日)           1.000000  0.000000
# p値(休日)                  -0.604121  0.084899
# 人口平均(休日)                 0.247727  0.520436
# 人口中央値(休日)                0.233979  0.544556
# 人口合計(休日)                 0.245102  0.525009
# 人口分散(休日)                 0.538653  0.134580
# 人口最大値(休日)                0.426556  0.252236
# 人口最小値(休日)               -0.155942  0.688685
# 発言者数平均(休日)               0.625091  0.071848
# 発言者数中央値(休日)              0.620107  0.074828
# 発言者数合計(休日)               0.624953  0.071930
# 発言者数分散(休日)               0.605795  0.083807
# 発言者数最大値(休日)              0.640240  0.063252
# 発言者数最小値(休日)              0.576989  0.103819
# 発言者数中央値/人口中央値(休日)        0.790578  0.011200
# convenience              0.407889  0.275809
# restaurant               0.589777  0.094612
# school                   0.581705  0.100363
# bus_stop                 0.348610  0.357865
# hotel                    0.459986  0.212825
# ...

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/re/ソーシャルセンサ性能との相関(休日).csv')

# %%
df_extraction = df_merge.loc[:,['人口合計','発言者数合計','観光客全体','居住者数（総数）']]

# %%
df_extraction.corr()
# Out:
#               人口合計    発言者数合計     観光客全体  居住者数（総数）
# 人口合計      1.000000  0.769015  0.045046 -0.112802
# 発言者数合計    0.769015  1.000000  0.357863 -0.444140
# 観光客全体     0.045046  0.357863  1.000000 -0.551014
# 居住者数（総数） -0.112802 -0.444140 -0.551014  1.000000

# %%
len(df_extraction.columns)
# Out:
# 4

# %%
tmp=[]
index=[]
for i in range(0,4):
    i_key = df_extraction.columns[i]
    for j in range(0,4):
        j_key = df_extraction.columns[j]
        if i >= j:
            continue
        else:
            corr, pvalue = stats.pearsonr(df_merge[i_key], df_merge[j_key])
            tmp.append([corr,pvalue])
            index.append(str(i_key)+ "&"+str(j_key))
df_ = pd.DataFrame(tmp,index=index, columns=['相関係数','p値'])

# %%
#df_.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/人口, 発言数と観光客, 居住者数の相関.csv')
