# %%
import pandas as pd
from scipy import signal, stats

# %%
df_facility = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/overpass/facility_numbers.csv',index_col=0)
df_corr = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/src/basic_analysis/基本統計量_work_holi.csv',index_col=0)
df_kankou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/kankou/fix_kankoukyaku.csv',index_col=0)
df_zinkou = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/zinkou/zinkou.csv',index_col=0)
df_distance = pd.read_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/distance/cal_distance.csv',index_col=0)

# %%
df_kankou = df_kankou.iloc[:,0]

# %%
df_distance = df_distance.iloc[:,8]

# %%
df_zinkou = df_zinkou.iloc[:,0]

# %%
df_corr = df_corr.iloc[0:13,:]

# %%
df_corr
# Out:
#          相関係数            p値  相関係数 (平日)       p値 (平日)  相関係数 (休日)       p値 (休日)
# 東京駅 -0.383555  3.075326e-14   0.620190  3.203299e-27   0.793205  1.288720e-27  \
# 嵐山   0.653550  7.802838e-46   0.597885  3.875152e-25   0.618376  5.252466e-14
# 中京区 -0.186082  3.513405e-04   0.055679  3.855379e-01   0.233588  1.023838e-02
# 金閣寺  0.019234  7.141892e-01  -0.020846  7.454373e-01  -0.086233  3.490196e-01
# 清水寺  0.739777  1.934243e-64   0.631705  1.082056e-28   0.734605  1.313650e-21
# 学生街  0.135085  9.772009e-03   0.013047  8.389889e-01   0.043799  6.347885e-01
# 二条城  0.476659  4.200543e-22   0.255606  5.169066e-05   0.359969  5.385918e-05
# 東寺   0.180932  5.136091e-04   0.218914  5.585655e-04   0.296158  1.022392e-03
# 京都駅  0.692329  2.177144e-53   0.807913  9.826860e-58   0.722981  1.125435e-20
#
#         人口平均    人口中央値       人口合計          人口分散  ...  発言者数平均  発言者数中央値  発言者数合計
# 東京駅  1062355  1202992  387759850  142257252933  ...     203      180   74275  \
# 嵐山     13271    12286    4844123      10647239  ...       3        3    1435
# 中京区   502359   504733  183361385     535984480  ...      20       19    7357
# 金閣寺   171207   170789   62490734      48630493  ...       3        3    1334
# 清水寺   133314   130088   48659663     334391725  ...      16       14    5848
# 学生街   264123   260333   96405085     142359219  ...       5        5    2046
# 二条城   336931   336494  122980129      85780900  ...      11       11    4343
# 東寺    306050   311300  111708322     340225888  ...       4        4    1649
# 京都駅   520432   518560  189957943    3921620476  ...     223      209   81522
#
#      発言者数分散  発言者数標準偏差  発言者数最大値  発言者数最小値  発言者数四分位点(25%)  発言者数四分位点(75%)
# 東京駅    6464        80      544       77            148            232  \
# 嵐山       11         3       21        0              2              5
# 中京区      61         7       59        5             15             24
# 金閣寺       8         2       17        0              2              5
# 清水寺      76         8       57        1             10             21
# 学生街       4         2       16        0              4              7
# 二条城      29         5       37        1              8             15
# 東寺       10         3       19        0              2              6
# 京都駅    6100        78      486       80            169            274
#
#      発言者数中央値/人口中央値
# 東京駅       0.000150
# 嵐山        0.000244
# 中京区       0.000038
# 金閣寺       0.000018
# 清水寺       0.000108
# 学生街       0.000019
# 二条城       0.000033
# 東寺        0.000013
# 京都駅       0.000403
#
# [9 rows x 25 columns]

# %%
df_merge = df_corr.merge(df_facility,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_kankou,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_zinkou,left_index=True,right_index=True)

# %%
df_merge = df_merge.merge(df_distance,left_index=True,right_index=True)

# %%
df_merge
# Out:
#          相関係数            p値  相関係数 (平日)       p値 (平日)  相関係数 (休日)       p値 (休日)
# 東京駅 -0.383555  3.075326e-14   0.620190  3.203299e-27   0.793205  1.288720e-27  \
# 嵐山   0.653550  7.802838e-46   0.597885  3.875152e-25   0.618376  5.252466e-14
# 中京区 -0.186082  3.513405e-04   0.055679  3.855379e-01   0.233588  1.023838e-02
# 金閣寺  0.019234  7.141892e-01  -0.020846  7.454373e-01  -0.086233  3.490196e-01
# 清水寺  0.739777  1.934243e-64   0.631705  1.082056e-28   0.734605  1.313650e-21
# 学生街  0.135085  9.772009e-03   0.013047  8.389889e-01   0.043799  6.347885e-01
# 二条城  0.476659  4.200543e-22   0.255606  5.169066e-05   0.359969  5.385918e-05
# 東寺   0.180932  5.136091e-04   0.218914  5.585655e-04   0.296158  1.022392e-03
# 京都駅  0.692329  2.177144e-53   0.807913  9.826860e-58   0.722981  1.125435e-20
#
#         人口平均    人口中央値       人口合計          人口分散  ...  発言者数四分位点(75%)
# 東京駅  1062355  1202992  387759850  142257252933  ...            232  \
# 嵐山     13271    12286    4844123      10647239  ...              5
# 中京区   502359   504733  183361385     535984480  ...             24
# 金閣寺   171207   170789   62490734      48630493  ...              5
# 清水寺   133314   130088   48659663     334391725  ...             21
# 学生街   264123   260333   96405085     142359219  ...              7
# 二条城   336931   336494  122980129      85780900  ...             15
# 東寺    306050   311300  111708322     340225888  ...              6
# 京都駅   520432   518560  189957943    3921620476  ...            274
#
#      発言者数中央値/人口中央値  convenience  restaurant  school  bus_stop  hotel  観光客全体
# 東京駅       0.000150           22          88       1        49      8   25.3  \
# 嵐山        0.000244            0           7       0         0      0   19.6
# 中京区       0.000038           17          58       1        17      6    6.2
# 金閣寺       0.000018            4           9       0        17      0   11.8
# 清水寺       0.000108            3          24       1         8      2   40.2
# 学生街       0.000019            4           1       0        21      0    7.6
# 二条城       0.000033            7          23       1        11      1   18.9
# 東寺        0.000013            3           3       0        24      0   32.9
# 京都駅       0.000403           21          83       1        60     37   32.9
#
#      居住者数（総数）          駅距離
# 東京駅      1161     0.000000
# 嵐山          6   869.167553
# 中京区     17311     0.000000
# 金閣寺      9637  1078.277894
# 観光客全体          0.517349 -0.315836   0.748473 -0.750171   0.718695 -0.573885
# 居住者数（総数）      -0.312095  0.043469  -0.816973  0.585332  -0.766875  0.471188
# 駅距離            0.345060  0.453832   0.022794 -0.036081  -0.054496 -0.058115
#
#                    人口平均     人口中央値      人口合計      人口分散  ...  発言者数四分位点(75%)
# 相関係数          -0.636081 -0.644469 -0.636081 -0.586957  ...      -0.080780  \
# p値            -0.241507 -0.230298 -0.241507 -0.132108  ...      -0.215081
# 相関係数 (平日)      0.236628  0.249465  0.236628  0.333913  ...       0.669331
# p値 (平日)       -0.211026 -0.219712 -0.211026 -0.242269  ...      -0.367842
# 相関係数 (休日)      0.360351  0.376410  0.360351  0.456427  ...       0.619957
# p値 (休日)       -0.237250 -0.237232 -0.237250 -0.188542  ...      -0.300829
# 人口平均           1.000000  0.997521  1.000000  0.854216  ...       0.746618
# 人口中央値          0.997521  1.000000  0.997521  0.888373  ...       0.736058
# 人口合計           1.000000  0.997521  1.000000  0.854215  ...       0.746618
# 人口分散           0.854216  0.888373  0.854215  1.000000  ...       0.604278
# 人口標準偏差         0.892584  0.920814  0.892584  0.992751  ...       0.689507
# 人口最大値          0.986005  0.993620  0.986005  0.920846  ...       0.767104
# 人口最小値          0.469138  0.408590  0.469139 -0.047393  ...       0.293283
# 人口四分位点(25%)    0.948398  0.924228  0.948398  0.645878  ...       0.713649
# 人口四分位点(75%)    0.994452  0.999081  0.994451  0.903215  ...       0.748488
# 発言者数平均         0.769194  0.760640  0.769194  0.637787  ...       0.999071
# 発言者数中央値        0.754501  0.744168  0.754501  0.612394  ...       0.999912
# 発言者数合計         0.769015  0.760533  0.769015  0.638156  ...       0.999053
# 発言者数分散         0.794987  0.792685  0.794987  0.704474  ...       0.989770
# 発言者数標準偏差       0.793409  0.789323  0.793409  0.690472  ...       0.993379
# 発言者数最大値        0.819215  0.817197  0.819215  0.726951  ...       0.986108
# 発言者数最小値        0.784113  0.777528  0.784113  0.663868  ...       0.996367
# 発言者数四分位点(25%)  0.759668  0.749824  0.759668  0.620412  ...       0.999707
# 発言者数四分位点(75%)  0.746618  0.736058  0.746618  0.604278  ...       1.000000
# 発言者数中央値/人口中央値  0.156407  0.149028  0.156407  0.121430  ...       0.727731
# convenience    0.877417  0.851503  0.877417  0.587388  ...       0.846952
# restaurant     0.832743  0.815316  0.832743  0.616766  ...       0.884921
# school         0.551810  0.528413  0.551810  0.327010  ...       0.528864
# bus_stop       0.757653  0.736102  0.757653  0.522492  ...       0.923932
# hotel          0.389756  0.351026  0.389756  0.088571  ...       0.843263
# 観光客全体          0.045047  0.054859  0.045046  0.121914  ...       0.367215
# 居住者数（総数）      -0.112802 -0.158132 -0.112802 -0.456124  ...      -0.436311
# 駅距離           -0.650157 -0.614968 -0.650157 -0.318904  ...      -0.480411
#
#                発言者数中央値/人口中央値  convenience  restaurant    school  bus_stop
# 人口合計           0.389756  0.045046 -0.112802 -0.650157
# 人口分散           0.088571  0.121914 -0.456124 -0.318904
# 人口標準偏差         0.201659  0.169856 -0.454803 -0.362783
# 人口最大値          0.362584  0.111598 -0.254079 -0.562412
# 人口最小値          0.453172 -0.254774  0.648352 -0.740480
# 人口四分位点(25%)    0.500180 -0.018743  0.124906 -0.760295
# 人口四分位点(75%)    0.354072  0.074088 -0.195173 -0.597237
# 発言者数平均         0.820387  0.358752 -0.443449 -0.483877
# 発言者数中央値        0.838340  0.359828 -0.433614 -0.486419
# 発言者数合計         0.819965  0.357863 -0.444140 -0.484408
# 発言者数分散         0.760930  0.345988 -0.475437 -0.467030
# 発言者数標準偏差       0.777110  0.366793 -0.474825 -0.468308
# 発言者数最大値        0.745610  0.349928 -0.477337 -0.473773
# 発言者数最小値        0.799774  0.337269 -0.447757 -0.486023
# 発言者数四分位点(25%)  0.832920  0.353288 -0.434492 -0.489162
# 発言者数四分位点(75%)  0.843263  0.367215 -0.436311 -0.480411
# 発言者数中央値/人口中央値  0.814543  0.431648 -0.635609 -0.137932
# convenience    0.710179  0.028608 -0.082884 -0.694094
# restaurant     0.731288  0.192927 -0.295044 -0.566357
# school         0.474754  0.294929 -0.148558 -0.449106
# bus_stop       0.804358  0.269918 -0.136050 -0.528351
# hotel          1.000000  0.332957 -0.204199 -0.417884
# 観光客全体          0.332957  1.000000 -0.551014  0.356805
# 居住者数（総数）      -0.204199 -0.551014  1.000000 -0.344559
# 駅距離           -0.417884  0.356805 -0.344559  1.000000
#
# [33 rows x 33 columns]

# %%
df_merge.columns
# Out:
# Index(['相関係数', 'p値', '相関係数 (平日)', 'p値 (平日)', '相関係数 (休日)', 'p値 (休日)', '人口平均',
#        '人口中央値', '人口合計', '人口分散', '人口標準偏差', '人口最大値', '人口最小値', '人口四分位点(25%)',
#        '人口四分位点(75%)', '発言者数平均', '発言者数中央値', '発言者数合計', '発言者数分散', '発言者数標準偏差',
#        '発言者数最大値', '発言者数最小値', '発言者数四分位点(25%)', '発言者数四分位点(75%)', '発言者数中央値/人口中央値',
#        'convenience', 'restaurant', 'school', 'bus_stop', 'hotel', '観光客全体',
#        '居住者数（総数）', '駅距離'],
#       dtype='object')

# %%
r_r = []
for i in df_merge.columns:
    corr, pvalue = stats.pearsonr(df_merge['相関係数'], df_merge[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge.columns, columns=['相関係数','p値'])

# %%
df_r
# Out:
#                    相関係数            p値
# 相関係数           1.000000  4.747586e-56
# p値            -0.223934  5.624419e-01
# 相関係数 (平日)      0.501296  1.691870e-01
# p値 (平日)       -0.400757  2.851086e-01
# 相関係数 (休日)      0.355244  3.481538e-01
# p値 (休日)       -0.225870  5.589777e-01
# 人口平均          -0.636081  6.554317e-02
# 人口中央値         -0.644469  6.097333e-02
# 人口合計          -0.636081  6.554315e-02
# 人口分散          -0.586957  9.659716e-02
# 人口標準偏差        -0.557603  1.187780e-01
# 人口最大値         -0.599854  8.772042e-02
# 人口最小値         -0.324634  3.940226e-01
# 人口四分位点(25%)   -0.591486  9.342033e-02
# 人口四分位点(75%)   -0.629432  6.931445e-02
# 発言者数平均        -0.112471  7.732768e-01
# 発言者数中央値       -0.092510  8.128787e-01
# 発言者数合計        -0.112327  7.735613e-01
# 発言者数分散        -0.166577  6.684021e-01
# 発言者数標準偏差      -0.144908  7.099123e-01
# 発言者数最大値       -0.185489  6.327924e-01
# 発言者数最小値       -0.146870  7.061249e-01
# 発言者数四分位点(25%) -0.101532  7.949284e-01
# 発言者数四分位点(75%) -0.080780  8.363292e-01
# 発言者数中央値/人口中央値  0.484570  1.861769e-01
# convenience   -0.408179  2.754352e-01
# restaurant    -0.264168  4.921620e-01
# school         0.026844  9.453472e-01
# bus_stop      -0.242959  5.287535e-01
# hotel          0.242521  5.295197e-01
# 観光客全体          0.517349  1.537514e-01
# 居住者数（総数）      -0.312095  4.135761e-01
# 駅距離            0.345060  3.631135e-01

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/ソーシャルセンサ性能との相関.csv')

# %%
r_r = []
for i in df_merge.columns:
    corr, pvalue = stats.pearsonr(df_merge['相関係数 (平日)'], df_merge[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge.columns, columns=['相関係数 (平日)','p値'])

# %%
df_r
# Out:
#                相関係数 (平日)        p値
# 相関係数            0.501296  0.169187
# p値             -0.453996  0.219618
# 相関係数 (平日)       1.000000  0.000000
# p値 (平日)        -0.774678  0.014229
# 相関係数 (休日)       0.956710  0.000053
# p値 (休日)        -0.612136  0.079751
# 人口平均            0.236628  0.539876
# 人口中央値           0.249465  0.517418
# 人口合計            0.236628  0.539876
# 人口分散            0.333913  0.379833
# 人口標準偏差          0.390116  0.299280
# 人口最大値           0.326050  0.391842
# 人口最小値          -0.253283  0.510811
# 人口四分位点(25%)     0.125756  0.747164
# 人口四分位点(75%)     0.277194  0.470224
# 発言者数平均          0.663019  0.051595
# 発言者数中央値         0.664106  0.051076
# 発言者数合計          0.662944  0.051632
# 発言者数分散          0.649175  0.058500
# 発言者数標準偏差        0.668160  0.049170
# 発言者数最大値         0.654687  0.055685
# 発言者数最小値         0.647538  0.059353
# 発言者数四分位点(25%)   0.660693  0.052717
# 発言者数四分位点(75%)   0.669331  0.048629
# 発言者数中央値/人口中央値   0.845908  0.004054
# convenience     0.337952  0.373735
# restaurant      0.531518  0.140834
# school          0.456959  0.216243
# bus_stop        0.404193  0.280608
# hotel           0.585855  0.097380
# 観光客全体           0.748473  0.020338
# 居住者数（総数）       -0.816973  0.007185
# 駅距離             0.022794  0.953585

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/ソーシャルセンサ性能との相関(平日).csv')

# %%
r_r = []
for i in df_merge.columns:
    corr, pvalue = stats.pearsonr(df_merge['相関係数 (休日)'], df_merge[i])
    r_r.append([corr, pvalue])
df_r = pd.DataFrame(r_r,index=df_merge.columns, columns=['相関係数 (休日)','p値'])

# %%
df_r
# Out:
#                相関係数 (休日)        p値
# 相関係数            0.355244  0.348154
# p値             -0.591685  0.093282
# 相関係数 (平日)       0.956710  0.000053
# p値 (平日)        -0.838943  0.004698
# 相関係数 (休日)       1.000000  0.000000
# p値 (休日)        -0.703637  0.034411
# 人口平均            0.360351  0.340767
# 人口中央値           0.376410  0.318048
# 人口合計            0.360351  0.340767
# 人口分散            0.456427  0.216848
# 人口標準偏差          0.500772  0.169706
# 人口最大値           0.443320  0.232018
# 人口最小値          -0.191030  0.622477
# 人口四分位点(25%)     0.236492  0.540115
# 人口四分位点(75%)     0.399827  0.286333
# 発言者数平均          0.622567  0.073348
# 発言者数中央値         0.617356  0.076505
# 発言者数合計          0.622208  0.073563
# 発言者数分散          0.616348  0.077125
# 発言者数標準偏差        0.640603  0.063054
# 発言者数最大値         0.640350  0.063192
# 発言者数最小値         0.609756  0.081258
# 発言者数四分位点(25%)   0.615474  0.077666
# 発言者数四分位点(75%)   0.619957  0.074919
# 発言者数中央値/人口中央値   0.703597  0.034425
# convenience     0.392813  0.295654
# restaurant      0.583379  0.099153
# school          0.577408  0.103509
# bus_stop        0.344269  0.364288
# hotel           0.456688  0.216551
# 観光客全体           0.718695  0.029141
# 居住者数（総数）       -0.766875  0.015898
# 駅距離            -0.054496  0.889256

# %%
#df_r.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/work_holi/ソーシャルセンサ性能との相関(休日).csv')

# %%
df_extraction = df_merge.loc[:,['人口合計','発言者数合計','観光客全体','居住者数（総数）']]

# %%
df_extraction.corr()
# Out:
#               人口合計    発言者数合計     観光客全体  居住者数（総数）
# 人口合計      1.000000  0.769015  0.045046 -0.112802
# 発言者数合計    0.769015  1.000000  0.357863 -0.444140
# 観光客全体     0.045046  0.357863  1.000000 -0.551014
# 居住者数（総数） -0.112802 -0.444140 -0.551014  1.000000

# %%
len(df_extraction.columns)
# Out:
# 4

# %%
tmp=[]
index=[]
for i in range(0,4):
    i_key = df_extraction.columns[i]
    for j in range(0,4):
        j_key = df_extraction.columns[j]
        if i >= j:
            continue
        else:
            corr, pvalue = stats.pearsonr(df_merge[i_key], df_merge[j_key])
            tmp.append([corr,pvalue])
            index.append(str(i_key)+ "&"+str(j_key))
df_ = pd.DataFrame(tmp,index=index, columns=['相関係数','p値'])

# %%
#df_.to_csv('/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/consideration/人口, 発言数と観光客, 居住者数の相関.csv')
