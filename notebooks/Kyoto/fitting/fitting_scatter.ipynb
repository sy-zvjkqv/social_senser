# %%
import pandas as pd
import numpy as np
from scipy import signal
from scipy import stats
from matplotlib import mlab
import matplotlib.pyplot as plt
plt.style.use('ggplot') #グラフのスタイル
plt.rcParams['figure.figsize'] = [12, 9] # グラフサイズ設定
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_selection import f_regression, mutual_info_regression
from sklearn.linear_model import LinearRegression
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from scipy.optimize import curve_fit

# %%
Arashi_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Arashiyama_3zi_2022.npy'

Highclass_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Highclass_3zi_2022.npy'

Kinkaku_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Kinkaku_3zi_2022.npy'

Kiyomizu_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Kiyomizu_3zi_2022.npy'

Lowclass_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Lowclass_3zi_2022.npy'

Nizyou_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Nizyou_3zi_2022.npy'

Touzi_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/npy/Touzi_3zi_2022.npy'

Kyotostation_npy_twitter_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/twitter/Kyoto/Kyotostaion2022/Kyotostation_3zi_2022.npy'

list_npy_twitter_PATH = [Arashi_npy_twitter_PATH, Highclass_npy_twitter_PATH, Lowclass_npy_twitter_PATH, Kinkaku_npy_twitter_PATH, Kiyomizu_npy_twitter_PATH, Nizyou_npy_twitter_PATH, Touzi_npy_twitter_PATH, Kyotostation_npy_twitter_PATH ]

# %%
Arashi_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Arashiyama_3zi_2022.npy'
Highclass_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Highclass_3zi_2022.npy'
Lowclass_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Lowclass_3zi_2022.npy'
Kinkaku_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Kinkaku_3zi_2022.npy'
Kiyomizu_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Kiyomizu_3zi_2022.npy'
Nizyou_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Nizyou_3zi_2022.npy'
Touzi_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Kyotostation.npy'

Kyotostation_npy_mobile_PATH = '/home/is/shuntaro-o/dev/compare_population_and_tweet_number/data/mobile/Kyoto/Kyotostation.npy'

list_npy_mobile_PATH = [Arashi_npy_mobile_PATH, Highclass_npy_mobile_PATH, Lowclass_npy_mobile_PATH, Kinkaku_npy_mobile_PATH, Kiyomizu_npy_mobile_PATH, Nizyou_npy_mobile_PATH, Touzi_npy_mobile_PATH, Kyotostation_npy_mobile_PATH]

# %%
Arashi_mobile = np.load(list_npy_mobile_PATH[0])
Arashi_twitter = np.load(list_npy_twitter_PATH[0])

Highclass_mobile = np.load(list_npy_mobile_PATH[1])
Highclass_twitter = np.load(list_npy_twitter_PATH[1])

Lowclass_mobile = np.load(list_npy_mobile_PATH[2])
Lowclass_twitter = np.load(list_npy_twitter_PATH[2])

Kinkaku_mobile = np.load(list_npy_mobile_PATH[3])
Kinkaku_twitter = np.load(list_npy_twitter_PATH[3])

Kiyomizu_mobile = np.load(list_npy_mobile_PATH[4])
Kiyomizu_twitter = np.load(list_npy_twitter_PATH[4])

Nizyou_mobile = np.load(list_npy_mobile_PATH[5])
Nizyou_twitter = np.load(list_npy_twitter_PATH[5])

Touzi_mobile = np.load(list_npy_mobile_PATH[6])
Touzi_twitter = np.load(list_npy_twitter_PATH[6])

Kyoto_station_mobile = np.load(list_npy_mobile_PATH[7])
Kyoto_station_twitter = np.load(list_npy_twitter_PATH[7])

# %%
Arashi_mobile_flatten = Arashi_mobile.flatten()

Highclass_mobile_flatten = Highclass_mobile.flatten()

Lowclass_mobile_flatten = Lowclass_mobile.flatten()

Kinkaku_mobile_flatten = Kinkaku_mobile.flatten()

Kiyomizu_mobile_flatten = Kiyomizu_mobile.flatten()

Nizyou_mobile_flatten = Nizyou_mobile.flatten()

Touzi_mobile_flatten = Touzi_mobile.flatten()

Kyoto_station_mobile_flatten = Kyoto_station_mobile.flatten()

# %%
Arashi_twitter_flatten = Arashi_twitter.flatten()

Highclass_twitter_flatten = Highclass_twitter.flatten()

Lowclass_twitter_flatten = Lowclass_twitter.flatten()

Kinkaku_twitter_flatten = Kinkaku_twitter.flatten()

Kiyomizu_twitter_flatten = Kiyomizu_twitter.flatten()

Nizyou_twitter_flatten = Nizyou_twitter.flatten()

Touzi_twitter_flatten = Touzi_twitter.flatten()

Kyoto_station_twitter_flatten = Kyoto_station_twitter.flatten()

# %%
mobile_flatten = Kyoto_station_mobile_flatten[0:2232]
twitter_flatten =Kyoto_station_twitter_flatten[0:2232]

# %%
X = mobile_flatten.reshape(-1,1)
y =twitter_flatten.reshape(-1,1)
f_test, _ = f_regression(X, y)
#f_test /= np.max(f_test)

mi = mutual_info_regression(X, y)
#mi /= np.max(mi)

plt.figure(figsize=(15, 10))
a, b = np.polyfit(X[:,0], y, 1)
# フィッティング直線
y2 = a * X + b
plt.plot(X, y2,color='black')
#.text(0.1,a*0.1+b, 'y='+ str(round(a,4)) +'x+'+str(round(b,4)))
plt.scatter(X[:, 0], y, edgecolor="black", s=20)
plt.xlabel("mobile", fontsize=14)
plt.ylabel("Geo", fontsize=14)
plt.title("F-test={:.2f}, MI={:.2f}".format(f_test[0], mi[0]), fontsize=16)
plt.show()
# Out:
# /home/is/shuntaro-o/dev/compare_population_and_tweet_number/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/is/shuntaro-o/dev/compare_population_and_tweet_number/.venv/lib/python3.10/site-packages/sklearn/utils/validation.py:1143: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
